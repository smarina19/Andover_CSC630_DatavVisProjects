# %% [markdown]
# # Local Election Data
# I'm going to look at the voting data for the area where I live (Eastern Washington). All of my data is from [ballotpedia.org](ballotpedia.org).
#
# ## Washington's 4th Congressional District - 2020 Voting Data
# <img src = "https://bloximages.newyork1.vip.townnews.com/yakimaherald.com/content/tncms/assets/v3/editorial/8/24/824bcb04-2a87-52d4-8085-db2ab0fd86ca/6152372a7784d.preview.jpg?resize=1024%2C663">

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([66.2, 33.6, 0.2])
mylabels = ["Dan Newhouse (R)", "Doug McKinley (D)", "Other/Write-in Votes (0.2)"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# ## WA-4 Race & Ethnicity Demographics

# %% [markdown]
# I thought it might also be interesting to look at the demographics in WA-4:

# %%
y = np.array([91.8, 3, 1.4, 2.6, 0.9, 1.1])
mylabels = ["White (91.8%)", "Two or More Races (3%)", "Other Race (1.4%)", "Asian (2.6%)", "Black (0.9%)", "American Indian/Alaska Native (1.1%)"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
y = np.array([96, 4])
mylabels = ["Not Hispanic (96%)","Hispanic (4%)"]
plt.pie(y, labels = mylabels)
plt.show()
